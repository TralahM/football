# %%
import pandas as pd

# %%
all_fixtures=pd.read_csv("All_Fixtures.csv")
all_teams=pd.read_csv("All_Teams.csv")
all_fixtures["home_team_badge"]=pd.Series(['' for i in range(len(all_fixtures))])

# %%
def get_badge(tid):
    toi=all_teams[ (all_teams["betradar_id"]==tid)]
    return toi.head(1)["crest_url"]
def get_label(tid):
    toi=all_teams[all_teams["betradar_id"]==tid]
    return toi.head(1)["team_abbreviation"]

# %%
all_fixtures['home_team_id'].apply(lambda x: get_badge(x))
# Out:
#                                                     0    \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10    http://upload.wikimedia.org/wikipedia/en/5/53/...
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# ...
